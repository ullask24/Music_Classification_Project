# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# 1. Get predictions for the validation set
print("Generating Specialist predictions...")
y_pred_probs = model.predict(val_ds)
y_pred = np.argmax(y_pred_probs, axis=1)

# 2. Get true labels from the val_ds
# Since datasets are batched, we need to concatenate them back
y_true = np.concatenate([y for x, y in val_ds], axis=0)
y_true = np.argmax(y_true, axis=1)

# 3. Create Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=GENRES, yticklabels=GENRES)
plt.title('Ventral Stream: Texture Specialist Confusion Matrix')
plt.xlabel('Predicted Genre')
plt.ylabel('True Genre')
plt.show()

# 4. Detailed Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=GENRES))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# 1. Get predictions for the validation set
print("Generating Specialist predictions...")
y_pred_probs = model.predict(val_ds)
y_pred = np.argmax(y_pred_probs, axis=1)

# 2. Get true labels from the val_ds
# Since datasets are batched, we need to concatenate them back
y_true = np.concatenate([y for x, y in val_ds], axis=0)
y_true = np.argmax(y_true, axis=1)

# 3. Create Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=GENRES, yticklabels=GENRES)
plt.title('Ventral Stream: Texture Specialist Confusion Matrix')
plt.xlabel('Predicted Genre')
plt.ylabel('True Genre')
plt.show()

# 4. Detailed Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=GENRES))

# %%
# Compare Individual vs Committee
tex_acc = accuracy_score(y_true, np.argmax(tex_probs, axis=1))
seq_acc = accuracy_score(y_true, np.argmax(seq_probs, axis=1))

results = pd.DataFrame({
    'Model': ['Texture Specialist', 'Sequence Specialist', 'The Committee'],
    'Accuracy': [tex_acc, seq_acc, ensemble_acc]
})

plt.figure(figsize=(8, 5))
sns.barplot(data=results, x='Model', y='Accuracy', palette='viridis')
plt.ylim(0, 1.0)
plt.title('Ensemble Synergy: Did the Committee improve results?')
plt.show()
